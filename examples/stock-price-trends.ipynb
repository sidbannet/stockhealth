# %% [markdown]
# # Future trend of the underlying
#
# ---
#
# Using Monte Carlos Simulation with Stochastic Volatility Model an underlying's future trend is laid out

# %%
import sys
sys.path.append('../')
from stockhealth.analyzer import TimeSeries as Ts
from stockhealth.simulation import MonteCarloWithTraining as Mcs
from stockhealth.training import Trends

# %%
goog = Ts('GOOG')
goog_trend = Trends(stock=goog)
sim = Mcs(trained_model=goog_trend, number_of_days=30)

# %%
sim.solve()
f, a = sim.plot()
